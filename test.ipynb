# %%
import requests

url = "https://www.ecfr.gov/api/versioner/v1/full/2026-07-13/title-14.xml"
resp = requests.get(url, params={"part": "107"}, timeout=60)

print(resp.status_code)      # 200 = success
print(resp.text[:2000])      # first 2000 chars of the XML
# Out:
# 200
# <?xml version="1.0"?>
# <DIV5 N="107" TYPE="PART" VOLUME="2" hierarchy_metadata="{&amp;quot;path&amp;quot;:&amp;quot;/on/_SUBSTITUTE_DATE_/title-14/part-107&amp;quot;,&amp;quot;citation&amp;quot;:&amp;quot;14 CFR Part 107&amp;quot;,&amp;quot;alternate_reference&amp;quot;:&amp;quot;FAR Part 107&amp;quot;}">
# <HEAD>PART 107&#x2014;SMALL UNMANNED AIRCRAFT SYSTEMS
# </HEAD>
# <AUTH>
# <HED>Authority:</HED><PSPACE>49 U.S.C. 106(f), 40101 note, 40103(b), 44701(a)(5), 46105(c), 46110, 44807.
# </PSPACE></AUTH>
# <SOURCE>
# <HED>Source:</HED><PSPACE>Docket FAA-2015-0150, Amdt. 107-1, 81 FR 42209, June 28, 2016, unless otherwise noted.
# </PSPACE></SOURCE>
# <DIV6 N="A" TYPE="SUBPART" VOLUME="2" hierarchy_metadata="{&amp;quot;path&amp;quot;:&amp;quot;/on/_SUBSTITUTE_DATE_/title-14/part-107/subpart-A&amp;quot;,&amp;quot;citation&amp;quot;:&amp;quot;14 CFR Part 107 Subpart A&amp;quot;,&amp;quot;alternate_reference&amp;quot;:&amp;quot;FAR Part 107 Subpart A&amp;quot;}">
# ...
